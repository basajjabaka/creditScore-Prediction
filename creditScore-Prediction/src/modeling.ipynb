# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import math
import os

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
import joblib

# %%
# Create directories if they don't exist
os.makedirs("models/labelEncoders", exist_ok=True)
os.makedirs("models/ordinalEncoders", exist_ok=True)

# %%
os.chdir("D:/cboobs/creditScore-Prediction/creditScore-Prediction")

# %%
df4 = pd.read_csv("data/cleaned_credit_FR_age_18_60.csv")
df5 = df4.copy()
df6 = df4.copy()

# %% [markdown]
# ### Label Encoding

# %%
# label encoding categorical features

catCols = df5.select_dtypes(include='object').columns.drop('Credit_Score')
leDict = {}

for col in catCols:
    le = LabelEncoder()
    df5[col] = le.fit_transform(df5[col])
    leDict[col] = le
    joblib.dump(le, f"models/labelEncoders/{col}_label_encoder.pkl")

# %%
# Label Encoding Target

leTarget = LabelEncoder()
df5['Credit_Score'] = leTarget.fit_transform(df5['Credit_Score'])  
joblib.dump(leTarget, f"models/labelEncoders/Target_label_encoder.pkl")
# Out:
# ['models/labelEncoders/Target_label_encoder.pkl']

# %%
df5.Credit_Score.value_counts()
# Out:
# 2    35125
# 1    18463
# 0    12174
# Name: Credit_Score, dtype: int64

# %%
catCols = df5.select_dtypes(include='object').columns.drop('Credit_Score')
catCols
# Out:
# Index(['Month', 'Occupation', 'Credit_Mix', 'Payment_of_Min_Amount',
#        'Payment_Behaviour'],
#       dtype='object')

# %%
df4.Credit_Score.value_counts()
# Out:
# Standard    35125
# Poor        18463
# Good        12174
# Name: Credit_Score, dtype: int64

# %%
leTarget.classes_
# Out:
# array(['Good', 'Poor', 'Standard'], dtype=object)

# %%
# Training the data

x = df5.drop('Credit_Score', axis=1)
y = df5['Credit_Score']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
# training function


def trainModel(model, paramGrid, x_train, y_train, x_test, y_test):
    grid = GridSearchCV(model, paramGrid, cv=5, scoring='accuracy', n_jobs=2)
    grid.fit(x_train, y_train)
    bestModel = grid.best_estimator_
    yPred = bestModel.predict(x_test)
    acc = accuracy_score(y_test, yPred)
    print("Best Parameters: ", grid.best_params_)
    print("Accuracy: ", acc)

    return bestModel, acc, grid.best_params_

# %%
tree1 = DecisionTreeClassifier(random_state=42, class_weight='balanced')
tree1_paramGrid = {
    'max_depth': [3, 5, 7, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

bestTree1, tree1Acc, tree1BestParams = trainModel(tree1, tree1_paramGrid, x_train, y_train, x_test, y_test)
# Out:
# Best Parameters:  {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy:  0.6824298639093743

# %%
rf = RandomForestClassifier(random_state=42, class_weight='balanced', n_jobs=2)
rf_paramGrid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 7, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

bestRF, rfAcc, rfBestParams = trainModel(rf, rf_paramGrid, x_train, y_train, x_test, y_test)
# Out:
# Best Parameters:  {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Accuracy:  0.7737398312172128

# %%
tree2 = ExtraTreesClassifier(random_state=42, class_weight='balanced', n_jobs=1)
tree2_paramGrid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 7, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

bestTree2, tree2Acc, tree2BestParams = trainModel(tree2, tree2_paramGrid, x_train, y_train, x_test, y_test)
# Out:
# Best Parameters:  {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# Accuracy:  0.7423401505359994

# %%
xgb = XGBClassifier(random_state=42, scale_pos_weight= (y_train == 0).sum() / (y_train == 1).sum(), use_label_encoder=False, eval_metric='logloss')
xgb_paramGrid = {
    'n_estimators': [100, 200],
    'max_depth': [3,5,7],
    "learning_rate": [0.01, 0.1, 0.2],
    "subsample": [0.7, 1.0],
    "colsample_bytree": [0.7, 1.0]
}

bestXGB, xgbAcc, xgbBestParams = trainModel(xgb, xgb_paramGrid, x_train, y_train, x_test, y_test)
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:15:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:16:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:30:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:31:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:32:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:33:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:38:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\HP\AppData\Roaming\Python\Python39\site-packages\xgboost\core.py:158: UserWarning: [12:39:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "scale_pos_weight", "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Parameters:  {'colsample_bytree': 1.0, 'learning_rate': 0.2, 'max_depth': 7, 'n_estimators': 200, 'subsample': 1.0}
# Accuracy:  0.7674294837679617

# %%
# save best model
joblib.dump(bestRF, "models/best_model_rf.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 # save best model
# ----> 2 joblib.dump(bestRF, "models/best_model_rf.pkl")
#
# NameError: name 'bestRF' is not defined

# %%
for col in df5.describe(include='object').columns:
    print('Column Name: ',col)
    print(df5[col].unique())
    print('='*60 )
# Out:
# Column Name:  Month
# ['January' 'July' 'August' 'February' 'March' 'May' 'June' 'April']
# ============================================================
# Column Name:  Occupation
# ['Scientist' 'Unknown' 'Teacher' 'Engineer' 'Entrepreneur' 'Developer'
#  'Lawyer' 'Media_Manager' 'Doctor' 'Journalist' 'Manager' 'Accountant'
#  'Musician' 'Mechanic' 'Writer' 'Architect']
# ============================================================
# Column Name:  Credit_Mix
# ['Unknown' 'Good' 'Standard' 'Bad']
# ============================================================
# Column Name:  Payment_of_Min_Amount
# ['No' 'NM' 'Yes']
# ============================================================
# Column Name:  Payment_Behaviour
# ['High_spent_Small_value_payments' 'Low_spent_Small_value_payments'
#  'High_spent_Medium_value_payments' 'High_spent_Large_value_payments'
#  'Unknown' 'Low_spent_Medium_value_payments'
#  'Low_spent_Large_value_payments']
# ============================================================
# Column Name:  Credit_Score
# ['Good' 'Standard' 'Poor']
# ============================================================

# %%
for col in df5.describe(include=['Float64', 'int64', 'float64']).columns:
    print('Column Name: ',col)
    # print(df5[col].unique())
    print('='*60 )
# Out:
# Column Name:  Age
# ============================================================
# Column Name:  Annual_Income
# ============================================================
# Column Name:  Monthly_Inhand_Salary
# ============================================================
# Column Name:  Num_Bank_Accounts
# ============================================================
# Column Name:  Num_Credit_Card
# ============================================================
# Column Name:  Interest_Rate
# ============================================================
# Column Name:  Num_of_Loan
# ============================================================
# Column Name:  Delay_from_due_date
# ============================================================
# Column Name:  Num_of_Delayed_Payment
# ============================================================
# Column Name:  Changed_Credit_Limit
# ============================================================
# Column Name:  Num_Credit_Inquiries
# ============================================================
# Column Name:  Outstanding_Debt
# ============================================================
# Column Name:  Credit_Utilization_Ratio
# ============================================================
# Column Name:  Total_EMI_per_month
# ============================================================
# Column Name:  Amount_invested_monthly
# ============================================================
# Column Name:  Monthly_Balance
# ============================================================

# %% [markdown]
# ### Ordinal Encoding

# %%
for col in df6.select_dtypes(include='object').columns:
    print('Column Name: ',col)
    print(df6[col].unique())
    print('='*60 )
# Out:
# Column Name:  Month
# ['January' 'July' 'August' 'February' 'March' 'May' 'June' 'April']
# ============================================================
# Column Name:  Occupation
# ['Scientist' 'Unknown' 'Teacher' 'Engineer' 'Entrepreneur' 'Developer'
#  'Lawyer' 'Media_Manager' 'Doctor' 'Journalist' 'Manager' 'Accountant'
#  'Musician' 'Mechanic' 'Writer' 'Architect']
# ============================================================
# Column Name:  Credit_Mix
# ['Unknown' 'Good' 'Standard' 'Bad']
# ============================================================
# Column Name:  Payment_of_Min_Amount
# ['No' 'NM' 'Yes']
# ============================================================
# Column Name:  Payment_Behaviour
# ['High_spent_Small_value_payments' 'Low_spent_Small_value_payments'
#  'High_spent_Medium_value_payments' 'High_spent_Large_value_payments'
#  'Unknown' 'Low_spent_Medium_value_payments'
#  'Low_spent_Large_value_payments']
# ============================================================
# Column Name:  Credit_Score
# ['Good' 'Standard' 'Poor']
# ============================================================

# %%
oeMonth = OrdinalEncoder(categories=[['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August']], handle_unknown='use_encoded_value', unknown_value=-1)
oeOccupation = OrdinalEncoder(categories=[['Scientist', 'Unknown', 'Teacher', 'Engineer', 'Entrepreneur', 
                                         'Developer','Lawyer', 'Media_Manager', 'Doctor', 'Journalist', 
                                         'Manager', 'Accountant','Musician', 'Mechanic', 'Writer', 'Architect']], handle_unknown='use_encoded_value', unknown_value=-1)

oeCreditMix = OrdinalEncoder(categories=[["Unknown", 'Poor', 'Standard', 'Good']], handle_unknown='use_encoded_value', unknown_value=-1)
oePayMinAmt = OrdinalEncoder(categories=[['No','NM','Yes']], handle_unknown='use_encoded_value', unknown_value=-1)
oePaymentBehaviour = OrdinalEncoder(categories=[['Unknown','Low_spent_Small_value_payments', 'Low_spent_Medium_value_payments', 'Low_spent_Large_value_payments', 
                                                'High_spent_Small_value_payments','High_spent_Medium_value_payments', 'High_spent_Large_value_payments']], handle_unknown='use_encoded_value', unknown_value=-1)

# %%
oeTarget = OrdinalEncoder(categories=[['Poor', 'Standard', 'Good']], handle_unknown='use_encoded_value', unknown_value=-1)
df6['Credit_Score'] = oeTarget.fit_transform(df6[['Credit_Score']]).ravel().astype(int)
joblib.dump(oeTarget, "models/ordinalEncoders/Target_ordinal_encoder.pkl")

print("Target ordinal encoder has been applied and saved successfully!")
# Out:
# ['models/ordinalEncoders/Target_ordinal_encoder.pkl']
